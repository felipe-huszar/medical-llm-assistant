# %% [markdown]
# # TC Fase3 - System (Single Colab)\nFluxo: Paciente -> Chroma -> Modelo FT -> Safety Gate -> Audit JSONL

# %%
# !pip -q install gradio chromadb langchain langchain-chroma langchain-huggingface transformers sentence-transformers

# %%
from google.colab import drive\ndrive.mount('/content/drive')

# %%
import sys\nsys.path.append('/content')  # ajuste se copiar módulos para outro path

# %% [markdown]
# ## Copie os arquivos da pasta `system_colab/` para `/content` e execute o app

# %%
# Exemplo: !python app_gradio.py
